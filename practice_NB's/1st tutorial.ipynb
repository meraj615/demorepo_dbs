# %% [markdown]
# ### Data Reading

# %%
df_csv=spark.read.format("csv").option("header",True)\
                    .option("inferSchema",True)\
                    .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.display()

# %% [markdown]
# ### Date Reading from json

# %%
df_json=spark.read.format("json").option("inferschema",True)\
                    .option("header",True)\
                    .option("multiline",False)\
                    .load("/Volumes/workspace/default/my_volume/drivers.json")

# %%
df_json.display()

# %%
df = spark.read.table("workspace.default.big_mart_sales")

# %%
df.display()

# %% [markdown]
# Schema Definition

# %% [markdown]
# ### Schema Definition

# %%
df_csv.printSchema()

# %% [markdown]
# ### Trying to change the schema

# %%
my_ddl_schema= '''
                Item_Identifier string,
                Item_Weight string,
                Item_Fat_Content string,
                Item_Visibility double,
                Item_Type string,
                Item_MRP double,
                Outlet_Identifier string,
                Outlet_Establishment_Year integer,
                Outlet_Size string,
                Outlet_Location_Type string,
                Outlet_Type string  
                '''

# %%
df_csv= spark.read.format('csv')\
        .schema(my_ddl_schema)\
        .option("header",True)\
        .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.display()

# %%
df_csv.printSchema()

# %% [markdown]
# ### struct_type() schema

# %%
from pyspark.sql.types import*
from pyspark.sql.functions import*

# %%
my_struct_schema= StructType([
                                StructField('Item_Identifier', StringType(), True),
                                StructField('Item_Weight', StringType(), True),
                                StructField('Item_Fat_Content', StringType(), True),
                                StructField('Item_Visibility', DoubleType(), True),
                                StructField('Item_Type', StringType(), True),
                                StructField('Item_MRP', DoubleType(), True),
                                StructField('Outlet_Identifier', StringType(), True),
                                StructField('Outlet_Establishment_Year', IntegerType(), True),
                                StructField('Outlet_Size', StringType(), True),
                                StructField('Outlet_Location_Type', StringType(), True),
                                StructField('Outlet_Type', StringType(), True),
])

# %%
df_csv= spark.read.format('csv')\
        .schema(my_struct_schema)\
        .option("header",True)\
        .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.printSchema()

# %% [markdown]
# ### SELECT Statements

# %%
df_sel= df_csv.select('Item_Identifier','Item_Weight','Item_Fat_Content').display()

# %%
df_col= df_csv.select(col('Item_Identifier'),col('Item_Weight'),col('Item_Fat_Content')).display()

# %% [markdown]
# ### ALIAS

# %%
df_csv.select(col('Item_Identifier').alias('Item_Id')).display()

# %% [markdown]
# ### Filter/Where

# %% [markdown]
# ### Scenario-1

# %%
df_csv.filter(col('Item_Fat_Content')=='Regular').display()

# %% [markdown]
# ### Scenario-2

# %%
df_csv.filter((col('Item_Type')=='Soft Drinks') & (col('Item_Weight')<10)).display()

# %%
from pyspark.sql.types import*
from pyspark.sql.functions import*

# %% [markdown]
# ### Scenario-3

# %%
df_csv.filter((col("Outlet_Location_Type").isin("Tier 1","Tier 2")) & col("Outlet_Size").isNull()).display()

# %%
df_csv.select(col("Item_Identifier").alias('id')).display()

# %% [markdown]
# ### withcolumnRenamed

# %%
df_csv.withColumnRenamed('Item_Weight','Item_wt').display()

# %% [markdown]
# ### withColumn

# %% [markdown]
# ### Scenario-1

# %%
df_csv.withColumn('flag',lit('new')).display()

# %% [markdown]
# ### Scenario-2

# %%
df_csv.withColumn("product",col('Item_Weight')*col('Item_MRP')).display()

# %%
df_csv.withColumn("Item_Fat_Content",regexp_replace(col('Item_Fat_Content'),"Regular","Reg"))\
    .withColumn("Item_Fat_Content",regexp_replace(col('Item_Fat_Content'),"Low Fat","LF"))\
    .display()

# %% [markdown]
# ### TypeCasting

# %%
df_csv.withColumn("Item_Weight",col("Item_Weight").cast("string")).printSchema()

# %%
df_csv.withColumn("Item_Weight",col("Item_Weight").cast("int")).printSchema()

# %%
df_csv.withColumn("Item_Weight",col("Item_Weight").cast("string")).printSchema()

# %% [markdown]
# ### Sort/OrderBy

# %%
df_csv.sort(col("Item_Weight").desc()).display()

# %%
df_csv.sort(['Item_Weight','Item_Visibility'],ascending=[0,0]).display()

# %%
df_csv.sort(["Item_Weight","Item_Visibility"],ascending=[0,1]).display()

# %% [markdown]
# ### limit

# %%
df_csv.limit(8).display()

# %% [markdown]
# ### Drop

# %%
df_csv.drop("Item_Visibility").display()

# %%
df_csv.drop('Item_Visibility','Item_Type').display()

# %% [markdown]
# ### Drop_Duplicate

# %%
df_csv.dropDuplicates().display()

# %%
df_csv.drop_duplicates(subset=['Item_Type']).display()

# %%
df_csv.distinct().display()

# %%
data1=[('1','Meera'),('2','Priya')]
schema1= 'id String, name String'
df1 = spark.createDataFrame(data=data1, schema = schema1)

data2=[('3','Faimeen'),('2','Maliha')]
schema2= 'id String, name String'
df2= spark.createDataFrame(data=data2, schema = schema2)

# %%
df1.display()

# %%
df2.display()

# %% [markdown]
# ### UNION

# %%
df1.union(df2).display()

# %%
data1=[('Meera','1'),('Priya','2')]
schema1= 'name String, id String'
df1 = spark.createDataFrame(data=data1, schema = schema1)
df1.display()

# %%
df1.unionByName(df2).display()

# %%
df1.union(df2).display()

# %% [markdown]
# ### String Functions

# %% [markdown]
# ### initcap()

# %%
from pyspark.sql.functions import initcap

# %%
df_csv.select(initcap('Item_Type')).display()

# %%
from pyspark.sql.functions import *

# %%
df_csv.select(lower('Item_Type').alias('Item_Type')).display()

# %%
df_csv.select(upper('Item_Type').alias('Item_Type')).display()

# %% [markdown]
# ### Date FUnctions

# %%
df_csv.withColumn("curr_date",current_date()).display()

# %%
from pyspark.sql.functions import date_add

# %%
from pyspark.sql.functions import current_date, date_add

df_csv = df_csv.withColumn(
    "curr_date",
    current_date()
)

df_csv = df_csv.withColumn(
    "Week_After",
    date_add("curr_date", 7)
)
display(df_csv)

# %%
df_csv.display()

# %%
from pyspark.sql.functions import *

# %%
df_csv=df_csv.withColumn("Week_before",date_sub("curr_date",7))
display(df_csv)

# %%
df_csv=df_csv.withColumn("Diffdate",datediff("Week_After","curr_date"))
display(df_csv)

# %%
from pyspark.sql.functions import date_format

# %%
df_csv = df_csv.withColumn(
    "Week_before",
    date_format("Week_before", "MM-dd-yyyy")
)
display(df_csv)

# %%
df_csv=spark.read.format("csv")\
    .option("header",True)\
    .option("inferSchema",True)\
    .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.display()

# %%
from pyspark.sql.functions import *

# %%
df_csv.select(col('Item_Identifier'),col('Item_Outlet_Sales')).display()

# %%
df_csv.limit(8).display()

# %%
df_csv.filter(col('Item_Identifier')=='FDS12').display()

# %%
df_csv.select(col("Item_Identifier").alias("item_id")).display()

# %%
df_csv.withColumnRenamed("Item_Identifier","item_id").display()

# %%
df_csv.withColumn("new_name",lit("trying_withColumn")).display()

# %%
from pyspark.sql.types import*
from pyspark.sql.functions import*

# %%
df_csv.printSchema()

# %%
from pyspark.sql.functions import*
from pyspark.sql.types import*

# %%
df_csv=df_csv.withColumn("Date",current_date())

# %%
from pyspark.sql.types import*
from pyspark.sql.functions import*

# %%
df_scv=df_csv.withColumn("Week_After",date_add("Date",7)).display()

# %%
df_csv=df_csv.withColumn("week_before",date_sub("Date",7)).display()

# %%
from pyspark.sql.functions import*
from pyspark.sql.types import*

# %%
df_csv=spark.read.format("csv")\
    .option("inferSchema",True)\
    .option("header",True)\
    .load("Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.select("Item_Identifier").display()

# %%
from pyspark.sql.functions import*

# %%
df_csv.withColumn("Item_Identifier",regexp_replace(col("Item_Identifier"),"FDA15","fd")).display()

# %%
df_csv.sort((col("Item_Weight")).desc()).display()

# %%
df_csv.sort(col("Item_Weight"),col("Item_Visibility"),ascending=[0,1]).display()

# %%
df_csv.drop(col("Item_Identifier")).display()

# %%
df_csv.dropDuplicates(["Item_Type"]).display()

# %%
data1=[("1","Meera"),("2","Priya")]
schema1= "id string,name string"
df1= spark.createDataFrame(data1,schema1)

# %%
df1.display()

# %%
data2=[("3","MAliha"),("4","Prathima")]
schema2="id string,name string"
df2=spark.createDataFrame(data2,schema2)
df2.display()

# %%
df1.union(df2).display()

# %% [markdown]
# ### Handling Nulls

# %% [markdown]
# ### Dropping NULLS

# %%
df_csv.dropna('any').display()

# %%
df_csv.dropna(subset=["Outlet_Size"]).display()

# %%
df_csv.dropna(subset=['Outlet_Type']).display()

# %%
df_csv.dropna('all').display()

# %%
df_csv.dropna(subset=['Outlet_Size']).display()

# %% [markdown]
# ### Filling Nulls

# %%
df=df_csv.fillna('NA')
df.display()

# %%
df_csv= df_csv.select(col('Item_Weight').cast("string"))

# %%
df.printSchema()

# %%
df_csv.printSchema()

# %%
df_csv.fillna("NA").display()

# %%
df_csv.printSchema()

# %%
my_ddl_schema='''
                Item_Identifier string ,
                Item_Weight string ,
                Item_Fat_Content string ,
                Item_Visibility double ,
                Item_Type string ,
                Item_MRP double,
                Outlet_Identifier string ,
                Outlet_Establishment_Year integer ,
                Outlet_Size string ,
                Outlet_Location_Type string ,
                Outlet_Type string ,
                Item_Outlet_Sales double
                '''

# %%
df_csv=spark.read.format("csv").option("header",True)\
                    .schema(my_ddl_schema)\
                    .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.printSchema()

# %%
df_csv.fillna("NA").display()

# %%
df_csv.fillna('NotAvailable', subset=['Item_Weight']).display()

# %%
df_json=spark.read.format("json").option("inferschema",True)\
                    .option("header",True)\
                    .option("multiline",False)\
                    .load("/Volumes/workspace/default/my_volume/drivers.json")

# %%
df_json.display()

# %%
df_csv.display()

# %% [markdown]
# ### Split && Indexing

# %%
from pyspark.sql.functions import*

# %%
df=df_csv.withColumn("Outlet_Type",split("Outlet_Type"," ")).display()

# %%
df_csv.withColumn("Outlet_Type",split("Outlet_Type"," ")[0]).display()

# %%
df_csv.withColumn("Outlet_Type",explode(split("Outlet_Type"," "))).display()

# %%
from pyspark.sql.functions import*

# %%
df=df_csv.withColumn("Outlet_Type",split("Outlet_Type"," "))

# %%
df.display()

# %%
df.withColumn("type_flag",array_contains("Outlet_Type","Type1")).display()

# %%
df2=df_csv.groupby("Item_Type").agg(sum("Item_MRP")).display()

# %%
from pyspark.sql.functions import*

# %%
df3=df_csv.groupby("Item_Type","Outlet_Size").agg(sum("Item_MRP").alias("sum")).display()

# %%
df3=df_csv.groupby("Item_Type","Outlet_Size")\
    .agg((sum("Item_MRP")).alias("Sum"),(avg("Item_MRP")).alias("AVG")).display()

# %%
df_csv=spark.read.format("csv").option("header",True)\
                    .option("inferSchema",True)\
                    .load("/Volumes/workspace/default/my_volume/BigMart Sales.csv")

# %%
df_csv.display()

# %%
from pyspark.sql.functions import*
from pyspark.sql.types import*

# %%
df_csv.withColumn("Outlet_Type",explode(split("Outlet_Type"," "))).display()

# %%
df_csv.groupBy("Item_Identifier").agg(sum("Item_MRP")).display()

# %%
data=[("user1","book1"),("user1","book2"),("user2","book1"),("user2","book2"),("user3","book1"),("user3","book2"),("user3","book3")]

schema="Users string,Books string"
df=spark.createDataFrame(data,schema)
df.display()

# %%
df.groupby("Users").agg(count("Books")).display()

# %%
df.groupby("Users").agg(collect_list("Books")).display()

# %% [markdown]
# ### Pivot

# %%
df_csv.groupby("Item_type").pivot("Outlet_Size").agg(avg("Item_MRP")).display()

# %% [markdown]
# ### When-Otherwise

# %%
df_csv.withColumn("Flag",when(col("Item_Type")=='Meat',"Non-Veg").otherwise("Veg")).display()

# %%
df_csv.withColumn("New_flag",when((col("Item_type")!="Meat") & (col("Item_MRP")>50),"Veg_expensive")\
    .when((col("Item_type")!="Meat") & (col("Item_MRP")<50),"Veg_cheap")\
    .otherwise("Non-Veg")).display()

# %% [markdown]
# ### Duplicates_rows by meraj!!!

# %%
df.groupby("Users").agg(count("Books").alias("cnt")).filter(count("Books")>2).display()

# %% [markdown]
# ### Joins

# %%
data1=[(1,"gaur","d01"),
        (2, 'kit',  'd02'),
        (3, 'sam',  'd03'),
        (4, 'tim',  'd03'),
        (5, 'aman', 'd05'),
        (6,'Meera','d06')]
schema1="Id int,Name string,Dept_id string"

data2=[('d01', 'HR'),
        ('d02', 'Marketing'),
        ('d03', 'Accounts'),
        ('d04', 'IT'),
        ('d05', 'Finance')]
schema2="Dept_id string,Dept_name string"

df1=spark.createDataFrame(data1,schema1)
df2=spark.createDataFrame(data2,schema2)

# %%
df1.display()

# %%
df2.display()

# %% [markdown]
# ### Text

# %%
df1.join(df2, df1.Dept_id == df2.Dept_id, "inner").display()

# %%
df1.join(df2, df1["Dept_id"] == df2["Dept_id"], "inner").display()

# %%
df2.join(df1, df1.Dept_id == df2.Dept_id, "left").display()

# %%
df1.join(df2, df1.Dept_id==df2.Dept_id,"right").display()

# %%
df1.join(df2, df1.Dept_id==df2.Dept_id,"full").display()

# %%
df2.join(df1, df1.Dept_id==df2.Dept_id,"anti").display()

# %%
from pyspark.sql.window import *

# %%
df_csv.withColumn("flag",row_number().over(Window.orderBy("Item_Identifier"))).display()

# %%
df_csv.display()

# %%
df_csv = df_csv.withColumn("flag",row_number().over(Window.orderBy("Item_Identifier"))).display()

# %%
from pyspark.sql.window import *
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_csv.withColumn("flag",row_number().over(Window.orderBy("Item_Identifier")))

# %%
df_csv.display()

# %%
df_csv=df_csv.withColumn("flag",row_number().over(Window.orderBy("Item_Identifier")))
df_csv.display()

# %%
df_csv.display()

# %%
from pyspark.sql.window import *
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_csv=df_csv.withColumn("cumm_sum",sum("Item_Weight").over(Window.orderBy("Item_Type")))
df_csv.display()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import *

# %%
df_csv.withColumn("cumm_sum",sum("Item_MRP").over(Window.orderBy("Item_Type").rowsBetween(Window.unboundedPreceding,Window.currentRow))).display()

# %%
df_csv.withColumn("Cumm_sum",sum("Item_MRP").over(Window.partitionBy("Item_Type").orderBy("Item_Type").rowsBetween(Window.unboundedPreceding,Window.currentRow))).display()

# %%
df_csv=df_csv.withColumn("RN",row_number().over(Window.partitionBy("Item_Identifier").orderBy("Item_Identifier")))
df_csv.display()

# %%
df_csv.filter(col('RN')==1).display()

# %%
def my_fun(A):
    if A is None:
       return None
    return A + 10

# %%
my_udf=udf(my_fun)

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType

# %%
df_csv.withColumn("New_Col",my_udf("Item_weight")).display()

# %% [markdown]
# ### Data Writing

# %%
df_csv.write.format("csv")\
    .save("/Volumes/workspace/default/my_volume/data.csv")

# %% [markdown]
# ### Writing Modes

# %% [markdown]
# ### APPEND

# %%
df_csv.write.format('csv')\
    .mode('append')\
    .save('/Volumes/workspace/default/my_volume/data.csv')

# %% [markdown]
# ### OVERWRITE

# %%
df_csv.write.format('csv')\
    .mode('overwrite')\
    .save('/Volumes/workspace/default/my_volume/data.csv')

# %% [markdown]
# ### ERROR

# %%
df_csv.write.format('csv')\
    .mode('error')\
    .save('/Volumes/workspace/default/my_volume/data.csv')

# %% [markdown]
# ### IGNORE

# %%
df_csv.write.format('csv')\
    .mode('ignore')\
    .save('/Volumes/workspace/default/my_volume/data.csv')

# %% [markdown]
# ### PARQUET

# %%
df_csv.write.format('parquet')\
    .mode('append')\
    .save('/Volumes/workspace/default/my_volume/data.parquet')

# %% [markdown]
# ### Table

# %%
df_csv.write.format('delta')\
    .mode('overwrite')\
    .saveAsTable('my_table')

# %% [markdown]
# ### SPARK SQL

# %% [markdown]
# ### CreateTempView

# %%
df_csv.createOrReplaceTempView('my_view')

# %%
# %sql
select * from my_view

# %%
# %sql
select Item_Identifier from my_view

# %%
# %sql
select count(*) from my_view

# %%
# %sql
select max(Item_MRP) from my_view

# %%
# %sql
select UPPER(Outlet_Type) from my_view

# %%
df_sql=spark.sql(""" select Item_Type, Item_MRP from my_view where Item_MRP > 100 """)

# %%
from pyspark.sql.window import *
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_csv.withColumn("flag",row_number().over(Window.partitionBy("Item_Type").orderBy("Item_type"))).display()

# %%
df_sql=spark.sql("select * from my_view")

# %%
df_sql.display()

# %%
df_csv.display()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_csv.withColumn("date",current_date()).display()
